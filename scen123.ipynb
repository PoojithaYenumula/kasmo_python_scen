# %%
import pandas as pd

# %%
customers_upd=pd.read_csv(r"C:\Users\Poojitha\Downloads\us_customer_data 1.csv")

# %%
print(customers_upd.head());
print(customers_upd.info());
customers_upd.columns
customers_upd.shape
customers_upd.isnull().sum()
# Out:
#    customer_id              name                        email         phone  \
# 0            1     Michelle Kidd           vayala@example.net  619-723-4258
# 1            2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2            3      Larry Torres         dsanchez@example.net  810-256-4505
# 3            4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4            5  Matthew Phillips        qwilliams@example.com  220-763-3522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status
# 0           Gold
# 1         Silver
# 2         Bronze
# ...

# %%
customers_upd.head(50)
# Out:
#     customer_id                   name                        email  \
# 0             1          Michelle Kidd           vayala@example.net
# 1             2            Brad Newton  taylorcatherine@example.net
# 2             3           Larry Torres         dsanchez@example.net
# 3             4         Kimberly Price    jessicaknight@example.com
# 4             5       Matthew Phillips        qwilliams@example.com
# 5             6  Darrell Gallagher DVM      larryharris@example.org
# 6             7           Louis Miller  patriciaelliott@example.org
# 7             8    Melissa Galloway MD   watsonbenjamin@example.net
# 8             9         Matthew Harvey          bgaines@example.net
# 9            10           Rachel White     whitemichael@example.org
# 10           11            Nicole Yang    archerheather@example.org
# 11           12      Christine Delgado         yfarrell@example.net
# 12           13         Joseph Brennan       khernandez@example.com
# ...

# %%
customers_upd['email']=customers_upd['email'].fillna(customers_upd['name'].str.replace(' ','').str.lower()+'@example.com')

# %%
customers_upd.head(50)
# Out:
#     customer_id                   name                         email  \
# 0             1          Michelle Kidd            vayala@example.net
# 1             2            Brad Newton   taylorcatherine@example.net
# 2             3           Larry Torres          dsanchez@example.net
# 3             4         Kimberly Price     jessicaknight@example.com
# 4             5       Matthew Phillips         qwilliams@example.com
# 5             6  Darrell Gallagher DVM       larryharris@example.org
# 6             7           Louis Miller   patriciaelliott@example.org
# 7             8    Melissa Galloway MD    watsonbenjamin@example.net
# 8             9         Matthew Harvey           bgaines@example.net
# 9            10           Rachel White      whitemichael@example.org
# 10           11            Nicole Yang     archerheather@example.org
# 11           12      Christine Delgado          yfarrell@example.net
# 12           13         Joseph Brennan        khernandez@example.com
# ...

# %%
customers_upd.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
customers_upd['phone'] =customers_upd['phone'].str.replace(r'[^0-9]','',regex=True)

# %%
customers_upd.head(250)
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              2       Brad Newton  taylorcatherine@example.net  5376741158
# 2              3      Larry Torres         dsanchez@example.net  8102564505
# 3              4    Kimberly Price    jessicaknight@example.com  4232229779
# 4              5  Matthew Phillips        qwilliams@example.com  2207633522
# ..           ...               ...                          ...         ...
# 245          246    Charles Graham     kennethmoore@example.net  8557356873
# 246          247  Connie Alexander      richarderic@example.org  2145344044
# 247          248     Emily Jackson       jchristian@example.net  9198655309
# 248          249     Vanessa Gould   meyerelizabeth@example.net  1056886071
# 249          250    Jeffrey Rogers           omar69@example.net  9474465448
#
# ...

# %%
customers_upd.loc[525]#just 9 numbers in phn_no
# Out:
# customer_id                                                 526
# name                                             Cristina Blake
# email                                         wwebb@example.org
# phone                                                 966258031
# address              748 Colleen Circles, Maynardtown, NH 62583
# registration_date                                    04-06-2025
# loyalty_status                                           Silver
# Name: 525, dtype: object

# %%
customers_upd.loc[289]#its got 12 numbers in phn_no
# Out:
# customer_id                                                 290
# name                                                Tony Barnes
# email                                      daniel85@example.com
# phone                                              309515738521
# address              162 Jeffrey Rapids, Lindsaymouth, OH 43140
# registration_date                                    19-09-2024
# loyalty_status                                             Gold
# Name: 289, dtype: object

# %%
customers_upd['phone']=customers_upd['phone'].str[:10]

# %%
customers_upd['phone'] =customers_upd['phone'].fillna('xxx-xxx-xxxx')

# %%
customers_upd.loc[customers_upd['phone'].str.len()<10,'phone']='xxx-xxx-xxxx'
customers_upd['registration_date'] = pd.to_datetime(customers_upd['registration_date'], dayfirst=True, errors='coerce')

# %%
customers_upd.to_csv('final_cust_data.csv', index=False)

# %%
customers_upd
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              2       Brad Newton  taylorcatherine@example.net  5376741158
# 2              3      Larry Torres         dsanchez@example.net  8102564505
# 3              4    Kimberly Price    jessicaknight@example.com  4232229779
# 4              5  Matthew Phillips        qwilliams@example.com  2207633522
# ..           ...               ...                          ...         ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  6389899441
# 996          997      Jodi Simpson           eric24@example.org  4836252940
# 997          998     Crystal Brown         pshaffer@example.net  3907473088
# 998          999    Gregory Duarte    caitlindunlap@example.org  2574098196
# 999         1000       Jason Walls        michael42@example.com  6923336880
#
# ...

# %%
customers_upd
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              2       Brad Newton  taylorcatherine@example.net  5376741158
# 2              3      Larry Torres         dsanchez@example.net  8102564505
# 3              4    Kimberly Price    jessicaknight@example.com  4232229779
# 4              5  Matthew Phillips        qwilliams@example.com  2207633522
# ..           ...               ...                          ...         ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  6389899441
# 996          997      Jodi Simpson           eric24@example.org  4836252940
# 997          998     Crystal Brown         pshaffer@example.net  3907473088
# 998          999    Gregory Duarte    caitlindunlap@example.org  2574098196
# 999         1000       Jason Walls        michael42@example.com  6923336880
#
# ...

# %%
customers_upd.loc[customers_upd['phone'].str.len()<10,'phone']='xxx-xxx-xxxx'

# %%
transaction_table=pd.read_csv(r"C:\Users\Poojitha\Downloads\transaction_data.csv")

# %%
transaction_table
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 0                 1          565  2992.47  2025-03-10 01:20:54
# 1                 2          323  2041.87  2025-01-02 15:24:19
# 2                 3          398   107.35  2025-02-16 03:49:01
# 3                 4           19      NaN  2025-04-30 15:26:23
# 4                 5          547  3063.28  2025-06-14 04:28:53
# ..              ...          ...      ...                  ...
# 995             996           60   712.47  2025-01-13 14:16:32
# 996             997          235  2125.18  2025-06-09 12:37:36
# 997             998          669  3069.08  2025-04-01 19:59:01
# 998             999          931  2262.75  2025-06-08 01:36:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 0             Sports     Debit Card       New York
# 1           Clothing           Cash       New York
# 2             Beauty     Debit Card         Online
# ...

# %%
merged_table=pd.merge(customers_upd,transaction_table,on="customer_id",how="inner")

# %%
merged_table
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              4    Kimberly Price    jessicaknight@example.com  4232229779
# 2              5  Matthew Phillips        qwilliams@example.com  2207633522
# 3              7      Louis Miller  patriciaelliott@example.org  1988627105
# 4              7      Louis Miller  patriciaelliott@example.org  1988627105
# ..           ...               ...                          ...         ...
# 995          995    Deanna Johnson            ycook@example.org  5763204824
# 996          995    Deanna Johnson            ycook@example.org  5763204824
# 997          997      Jodi Simpson           eric24@example.org  4836252940
# 998          998     Crystal Brown         pshaffer@example.net  3907473088
# 999          998     Crystal Brown         pshaffer@example.net  3907473088
#
# ...

# %%
merged_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merged_table['amount']=merged_table['amount'].fillna(merged_table['amount'].mean())

# %%
merged_table.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
merged_table
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              4    Kimberly Price    jessicaknight@example.com  4232229779
# 2              5  Matthew Phillips        qwilliams@example.com  2207633522
# 3              7      Louis Miller  patriciaelliott@example.org  1988627105
# 4              7      Louis Miller  patriciaelliott@example.org  1988627105
# ..           ...               ...                          ...         ...
# 995          995    Deanna Johnson            ycook@example.org  5763204824
# 996          995    Deanna Johnson            ycook@example.org  5763204824
# 997          997      Jodi Simpson           eric24@example.org  4836252940
# 998          998     Crystal Brown         pshaffer@example.net  3907473088
# 999          998     Crystal Brown         pshaffer@example.net  3907473088
#
# ...

# %%
high_value_transactions=merged_table[merged_table['amount']>1000]

# %%
high_value_transactions
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              4    Kimberly Price    jessicaknight@example.com  4232229779
# 2              5  Matthew Phillips        qwilliams@example.com  2207633522
# 3              7      Louis Miller  patriciaelliott@example.org  1988627105
# 6             10      Rachel White     whitemichael@example.org  4107299740
# ..           ...               ...                          ...         ...
# 991          991     Erica Fleming          erica85@example.net  6264536078
# 992          992    Thomas Stevens    vargasmatthew@example.org  3854544879
# 993          995    Deanna Johnson            ycook@example.org  5763204824
# 994          995    Deanna Johnson            ycook@example.org  5763204824
# 999          998     Crystal Brown         pshaffer@example.net  3907473088
#
# ...

# %%
high_value_transactions.to_csv("high_value_tran.csv",index=False)

# %%
high_value_transactions
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              4    Kimberly Price    jessicaknight@example.com  4232229779
# 2              5  Matthew Phillips        qwilliams@example.com  2207633522
# 3              7      Louis Miller  patriciaelliott@example.org  1988627105
# 6             10      Rachel White     whitemichael@example.org  4107299740
# ..           ...               ...                          ...         ...
# 991          991     Erica Fleming          erica85@example.net  6264536078
# 992          992    Thomas Stevens    vargasmatthew@example.org  3854544879
# 993          995    Deanna Johnson            ycook@example.org  5763204824
# 994          995    Deanna Johnson            ycook@example.org  5763204824
# 999          998     Crystal Brown         pshaffer@example.net  3907473088
#
# ...
